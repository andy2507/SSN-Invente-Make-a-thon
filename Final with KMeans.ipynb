# %% [markdown]
# # Importing the necessary libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import scipy
import os
import time
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.corpus import wordnet as wn

# %% [markdown]
# # NLTK Tokenise meanings
# - CC coordinating conjunction
# - CD cardinal digit
# - DT determiner
# - EX existential there (like: “there is” … think of it like “there exists”)
# - FW foreign word
# - IN preposition/subordinating conjunction
# - JJ adjective ‘big’
# - JJR adjective, comparative ‘bigger’
# - JJS adjective, superlative ‘biggest’
# - LS list marker 1)
# - MD modal could, will
# - NN noun, singular ‘desk’
# - NNS noun plural ‘desks’
# - NNP proper noun, singular ‘Harrison’
# - NNPS proper noun, plural ‘Americans’
# - PDT predeterminer ‘all the kids’
# - POS possessive ending parent’s
# - PRP personal pronoun I, he, she
# - PRP possessive pronoun my, his, hers
# - RB adverb very, silently,
# - RBR adverb, comparative better
# - RBS adverb, superlative best
# - RP particle give up
# - TO, to go ‘to’ the store.
# - UH interjection, errrrrrrrm
# - VB verb, base form take
# - VBD verb, past tense took
# - VBG verb, gerund/present participle taking
# - VBN verb, past participle taken
# - VBP verb, sing. present, non-3d take
# - VBZ verb, 3rd person sing. present takes
# - WDT wh-determiner which
# - WP wh-pronoun who, what
# - WP possessive wh-pronoun whose
# - WRB wh-abverb where, when
#
# ## We discard these categories for our task: CC, CD, DT, EX, IN, LS, MD, PDT, POS, PRP, TO, UH, WDT, WP, WP, WRB

# %% [markdown]
# # Spacy tokenise meanings (not using this, just for reference)
# - PERSON	People, including fictional.
# - NORP	Nationalities or religious or political groups.
# - FAC	Buildings, airports, highways, bridges, etc.
# - ORG	Companies, agencies, institutions, etc.
# - GPE	Countries, cities, states.
# - LOC	Non-GPE locations, mountain ranges, bodies of water.
# - PRODUCT	Objects, vehicles, foods, etc. (Not services.)
# - EVENT	Named hurricanes, battles, wars, sports events, etc.
# - WORK_OF_ART	Titles of books, songs, etc.
# - LAW	Named documents made into laws.
# - LANGUAGE	Any named language.
# - DATE	Absolute or relative dates or periods.
# - TIME	Times smaller than a day.
# - PERCENT	Percentage, including ”%“.
# - MONEY	Monetary values, including unit.
# - QUANTITY	Measurements, as of weight or distance.
# - ORDINAL	“first”, “second”, etc.
# - CARDINAL	Numerals that do not fall under another type.

# %%
#words from the given corpus
wordss = []
for line in open('Targets.txt'):
    wordss.append(line[:-1])

# %% [markdown]
# # GloVe embeddings
# - Link: http://nlp.stanford.edu/data/glove.6B.zip
# - Run the following code to get the embeddings from the official site for GloVe
# - zip file was downloaded and extracted

# %%
os.chdir('glove.6B')

# %%
os.listdir()
# Out:
# ['glove.6B.200d.txt',
#  'glove.6B.50d.txt',
#  'glove.6B.100d.txt',
#  'glove.6B.300d.txt']

# %%
#Loading embeddings from GloVe 
embeddings = {}

f = open('glove.6B.100d.txt',encoding="utf8")

for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings[word] = coefs

f.close()
print('Loaded %s word vectors.' % len(embeddings))
# Out:
# Loaded 400000 word vectors.

# %%
#to calculate elapsed time
class ElapsedTimer(object):
    def __init__(self):
        self.start_time = time.time()
    def elapsed(self,sec):
        if sec < 60:
            return str(sec) + " sec"
        elif sec < (60 * 60):
            return str(sec / 60) + " min"
        else:
            return str(sec / (60 * 60)) + " hr"
    def elapsed_time(self):
        print("Elapsed: %s " % self.elapsed(time.time() - self.start_time) )

# %%
#to get entities using nltk
def entities_with_nltk(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
#to get the nearest neighbours using cosine similarity
def get_neighbours(s):
    res = {}
    for i in embeddings:
        if s not in embeddings:
            return res
        res[i] = scipy.spatial.distance.cosine(embeddings[i],embeddings[s])
    sorted_keys = sorted(res, key=res.get) 
    return sorted_keys

# %%
#to get the words that can be used for prediction
def get_possible_words(s):
    words = []
    exceptions = ['CC', 'CD', 'DT', 'EX', 'IN', 'LS', 'MD', 'PDT', 'POS', 'PRP', 'TO', 'UH', 'WDT', 'WP', 'WP', 'WRB','.',',']
    for i in s:
        if i[1] not in exceptions and len(i[0])>3:
            words.append(i[0])
    return words

# %%
#to get the answer
def get_answer(words,word):
    for i in words:
        s = get_neighbours(i)
        for k in s:
            if(len(k)==len(word)):
                if(compare(k,word)==True):
                    return k
    return ""

# %%
#to compare two words
def compare(a,b):
    for i in range(len(a)):
        if b[i]=='_':
            pass
        else:
            if(a[i]!=b[i]):
                return False
    return True

# %%
#to get word
def get_word(sent,word):
    categories = entities_with_nltk(sent)
    words = get_possible_words(categories)
    timer = ElapsedTimer()
    ans = get_answer(words, word)
    timer.elapsed_time()
    return ans

# %%
os.chdir("..")
os.listdir()
# Out:
# ['Evaluation.csv',
#  'Approach.docx',
#  '.ipynb_checkpoints',
#  'Consolidated-Copy1.ipynb',
#  'Trials word2vec.ipynb',
#  'Approach.pdf',
#  'results_with_kmeans.csv',
#  'results.csv',
#  'glove.6B',
#  'Final with KMeans-Copy1.ipynb',
#  'eval.csv',
#  'Final with KMeans.ipynb',
#  'Targets.txt',
#  'Final.ipynb',
#  'kmeans_model',
#  'Consolidated.ipynb',
#  'Consolidated-Copy2.ipynb']

# %%
evaluation = pd.read_csv('eval.csv',sep = ',')

# %%
evaluation.head()
# Out:
#             Masked                                            Meaning
# 0    C o _ _ n t h  the modern Greek port near the site of the anc...
# 1    _ e c e i _ e             get something; come into possession of
# 2    _ o l l a g _  a paste-up made by sticking together pieces of...
# 3        t _ _ s h       worthless material that is to be disposed of
# 4  D e _ a w _ r _  a river that rises in the Catskills in southea...

# %%
def remove_space(x):
    x = x.lower()
    letters = [i for i in x]
    s = ""
    for i in letters:
        if i!=' ':
            s = s+i
    return s
evaluation['Masked'] = evaluation['Masked'].apply(lambda x: remove_space(x))

# %% [markdown]
# # Let us try evaluating this to see how it goes

# %%
sent = "a garden plant with purple flowers that smell very pleasant."
word = "l_v_nd_r"

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /home/andrea/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/andrea/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
get_word(sent,word)
# Out:
# Elapsed: 29.961535215377808 sec
# 'lavender'

# %% [markdown]
# # Now applying it to the entire dataset

# %%
evaluation['Answer']=evaluation.apply(lambda x: get_word(x.Meaning, x.Masked), axis=1)
# Out:
# Elapsed: 30.494628190994263 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-688df80acaa5> in <module>
# ----> 1 evaluation['Answer']=evaluation.apply(lambda x: get_word(x.Meaning, x.Masked), axis=1)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     288             for i, v in enumerate(series_gen):
#     289                 # ignore SettingWithCopy here in case the user mutates
# --> 290                 results[i] = self.f(v)
#     291                 if isinstance(results[i], ABCSeries):
#     292                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-30-688df80acaa5> in <lambda>(x)
# ----> 1 evaluation['Answer']=evaluation.apply(lambda x: get_word(x.Meaning, x.Masked), axis=1)
#
# <ipython-input-16-df35b75c0c9c> in get_word(sent, word)
#       4     words = get_possible_words(categories)
#       5     timer = ElapsedTimer()
# ----> 6     ans = get_answer(words, word)
#       7     timer.elapsed_time()
#       8     return ans
#
# <ipython-input-14-8408965a8f36> in get_answer(words, word)
#       2 def get_answer(words,word):
#       3     for i in words:
# ----> 4         s = get_neighbours(i)
#       5         for k in s:
#       6             if(len(k)==len(word)):
#
# <ipython-input-28-47119ad9a8cf> in get_neighbours(s)
#       5         if s not in embeddings:
#       6             return res
# ----> 7         res[i] = scipy.spatial.distance.cosine(embeddings[i],embeddings[s])
#       8     sorted_keys = sorted(res, key=res.get)
#       9     return sorted_keys
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/spatial/distance.py in cosine(u, v, w)
#     773     # cosine distance is also referred to as 'uncentered correlation',
#     774     #   or 'reflective correlation'
# --> 775     return correlation(u, v, w=w, centered=False)
#     776
#     777
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/spatial/distance.py in correlation(u, v, w, centered)
#     723         u = u - umu
#     724         v = v - vmu
# --> 725     uv = np.average(u * v, weights=w)
#     726     uu = np.average(np.square(u), weights=w)
#     727     vv = np.average(np.square(v), weights=w)
#
# KeyboardInterrupt:

# %% [markdown]
# # The previous function was run on a GPU enabled notebook
# - It used about 20 seconds per word.
# - The answers were stored in the column 'Answers'
# - The results obtained are stored in a file called 'results.csv' and loaded here for reference
# - It was able to predict the answer for most of the words, in some cases (very rare) predicted the wrong words

# %%
results = pd.read_csv('results.csv')
results = results.drop(results.columns[0],axis=1)

# %%
results
# Out:
#           Masked                                            Meaning  \
# 0        co__nth  the modern Greek port near the site of the anc...
# 1        _ecei_e             get something; come into possession of
# 2        _ollag_  a paste-up made by sticking together pieces of...
# 3          t__sh       worthless material that is to be disposed of
# 4       de_aw_r_  a river that rises in the Catskills in southea...
# ..           ...                                                ...
# 246       hic_e_  a small inflamed elevation of the skin; a pust...
# 247           no                                         a negative
# 248      sol_e_t  a liquid substance capable of dissolving other...
# 249        _ump_                          resembling a garbage dump
# 250  co__i_at_on  something that is compiled (as into a single b...
#
#           Answer
# 0        corinth
# 1        receive
# 2        collage
# 3          trash
# 4       delaware
# ..           ...
# 246       hickey
# 247           no
# 248      solvent
# 249        lumpy
# 250  combination
#
# [251 rows x 3 columns]

# %%
#answers that weren't found
results[results['Answer'].isnull()]
# Out:
#             Masked                                            Meaning Answer
# 11         f_otp_d                      a highwayman who robs on foot    NaN
# 35         skyja__                  subject an aircraft to air piracy    NaN
# 81      su__osa_l_        capable of being inferred on slight grounds    NaN
# 84   admi_is___b_e           capable of being administered or managed    NaN
# 86         __rmute                 change the order or arrangement of    NaN
# 114         __calm                                        make steady    NaN
# 120       shu_d__y                              provoking fear terror    NaN
# 125      _a_writ_r  someone who writes comic material for public p...    NaN
# 132     _eth_sel__                                     (Old Testament    NaN
# 205    c_ns_ern__e     fill with anxiety, dread, dismay, or confusion    NaN
# 244     _apa___ate             make legally capable or qualify in law    NaN

# %% [markdown]
# # Using clustering to group similar words and improve performance
# - Here I have experimented with KMeans from sklearn library to group similar words into 5 clusters to see if it improves the run time

# %% [markdown]
# # Importing the necessary libraries

# %%
from sklearn.cluster import KMeans
import pickle

# %% [markdown]
# # Initialising KMeans() with 5 clusters and 300 iterations
# - So the idea now is to find the word's cluster and search for words within that cluster

# %%
kmeans = KMeans(
    init="random",
    n_clusters=5,
    n_init=10,
    max_iter=300,
    random_state=42
)

# %% [markdown]
# # Fitting the model
# - I have stored the model I have trained in the files. Try not to run this again as it can lead to different clusters
# - To save the model: pickle.dump(model, open(filename, 'wb'))
# - To load saved model from local directory: model = pickle.load(open(filename, 'rb'))

# %%
#getting embeddings alone
dat = np.array(list(embeddings.values()))

# %%
kmeans.fit(dat)
# Out:
# KMeans(init='random', n_clusters=5, random_state=42)

# %%
pickle.dump(kmeans,open('kmeans_model','wb'))

# %% [markdown]
# # Getting the words alone from the embeddings dictionary

# %%
corpus_words = list(embeddings.keys())

# %%
cluster_centers = kmeans.cluster_centers_

# %% [markdown]
# # Storing labels

# %%
labels = kmeans.labels_

# %% [markdown]
# # For evaluation let's check the words from a given cluster to see if they hold similarities.
# - From this we observe that words that correspond to the 5th cluster are related to currencies and units. Voila! it has worked!

# %%
count=0
for i in range(400000):
    if labels[i]==1:
        count+=1
        if(count<=30):
            print(corpus_words[i])
print(count)
# Out:
# kuh
# née
# duh
# fah
# luh
# mahn
# shuh
# meh
# zah
# sih
# juh
# eduard
# sahn
# yoh
# mehd
# nuh
# ehl
# ehn
# herve
# y.
# puh
# vich
# hahm
# skee
# horst
# dool
# reh
# z.
# konstantin
# rahm
# 116190

# %% [markdown]
# # Creating a dictionary representing these clusters

# %%
cluster_dict={}
for i in range(400000):
    if labels[i] not in cluster_dict:
        cluster_dict[labels[i]]=[]
    cluster_dict[labels[i]].append(corpus_words[i])

# %% [markdown]
# # Now for the testing!

# %%
cluster_dict[1]`
# Out:
# ['kuh',
#  'née',
#  'duh',
#  'fah',
#  'luh',
#  'mahn',
#  'shuh',
#  'meh',
#  'zah',
#  'sih',
#  'juh',
#  'eduard',
#  'sahn',
#  'yoh',
#  'mehd',
#  'nuh',
#  'ehl',
#  'ehn',
#  'herve',
#  'y.',
#  'puh',
#  'vich',
#  'hahm',
#  'skee',
#  'horst',
#  'dool',
#  'reh',
#  'z.',
#  'konstantin',
#  'rahm',
#  'massoud',
#  'toder',
#  'jerzy',
#  'eed',
#  'keer',
#  'voh',
#  'odierno',
#  'meen',
#  'zhahn',
#  'phan',
#  'norbert',
#  'beel',
#  'konrad',
#  'asefi',
#  'klitschko',
#  'vitaly',
#  'seh',
#  'kemal',
#  'mohd',
#  'martino',
#  'chowdhury',
#  '1w',
#  'mahl',
#  'tih',
#  '202-887-8334',
#  'ereli',
#  'vyacheslav',
#  'avila',
#  'daoud',
#  'tahr',
#  'shum',
#  'gissin',
#  'vah',
#  'zalmay',
#  'andya',
#  'valero',
#  'fawzi',
#  'rohan',
#  'ivanko',
#  'egeland',
#  'asher',
#  'morin',
#  'shoh',
#  'yasin',
#  'micheletti',
#  'faris',
#  'uhn',
#  'murat',
#  'naji',
#  'joh',
#  'persie',
#  'regev',
#  'skakel',
#  'koenig',
#  'khai',
#  'ahk',
#  'boyer',
#  'matti',
#  'kahl',
#  'dimitris',
#  '202-887-8338',
#  'lih',
#  'kow',
#  'kohr',
#  'vasily',
#  'johndroe',
#  'yury',
#  'armin',
#  'khalaf',
#  'dih',
#  'blazy',
#  'kwah',
#  'georgy',
#  'hoshyar',
#  'artd',
#  'nikos',
#  'douste',
#  'brinkema',
#  'giuliano',
#  'valls',
#  'qassim',
#  'laszlo',
#  'sohn',
#  'ahd',
#  'dusan',
#  'velasquez',
#  'gabor',
#  'shalikashvili',
#  'volker',
#  'zy',
#  'afzal',
#  'sadiq',
#  'angelos',
#  'vogt',
#  'hyung',
#  'bahd',
#  'constantin',
#  'marsha',
#  'ayub',
#  'reis',
#  'loy',
#  'sulaiman',
#  'reiter',
#  'mansur',
#  'cheh',
#  'sebelius',
#  'kidsday',
#  'kazimierz',
#  'rinpoche',
#  'kenney',
#  'pehr',
#  'piotr',
#  '202-887-8316',
#  'vadim',
#  'naroff',
#  'fortier',
#  'pirro',
#  'buchan',
#  'morkel',
#  'graner',
#  'stanislas',
#  'tomasz',
#  'hosseini',
#  'dabbagh',
#  'alden',
#  'taher',
#  'ganic',
#  'paulus',
#  'vang',
#  'naimi',
#  'zhan',
#  'kazemi',
#  'darnell',
#  'dehl',
#  'faraj',
#  'mahd',
#  'bogdan',
#  'christos',
#  'solberg',
#  'raanan',
#  'aftab',
#  'pfc.',
#  'peiris',
#  'pratap',
#  'mounir',
#  'tejan',
#  'beazley',
#  'reeker',
#  'bastian',
#  'fedotov',
#  'pronk',
#  'olav',
#  'giorgos',
#  'moyo',
#  'jeh',
#  'dahm',
#  'thibault',
#  'farris',
#  'vur',
#  'rohn',
#  'moffat',
#  'pasquale',
#  'stanisław',
#  'wald',
#  'montes',
#  'aurelio',
#  'nguyễn',
#  'lipman',
#  'mihd',
#  'schuyler',
#  'walther',
#  'jaafar',
#  'mook',
#  'krzysztof',
#  'hassoun',
#  'torrijos',
#  'nanayakkara',
#  'sloot',
#  'zacks',
#  'ioan',
#  'vih',
#  'lazar',
#  'eugen',
#  'jih',
#  'ahf',
#  'steffen',
#  'schaeuble',
#  'frs',
#  'geller',
#  'hoekstra',
#  'juma',
#  'romulo',
#  'noe',
#  'atef',
#  'kovalainen',
#  'mikhailov',
#  'morne',
#  'halutz',
#  'lahood',
#  'daud',
#  'nunes',
#  'meel',
#  'brito',
#  'heim',
#  'geragos',
#  'władysław',
#  'shigeru',
#  'quattrone',
#  'jianchao',
#  'sevan',
#  'feh',
#  'amjad',
#  'zal',
#  'wuh',
#  'sidebottom',
#  'poul',
#  '202-887-8307',
#  'naveed',
#  'monika',
#  'alexy',
#  'droo',
#  'leszek',
#  'abbasi',
#  'neen',
#  'jesús',
#  'stanislaw',
#  'heymann',
#  'veneman',
#  'rdeneh',
#  'murr',
#  'yaalon',
#  'mujahid',
#  'yeoh',
#  'kristof',
#  'gopal',
#  'sicherle',
#  'sayn',
#  'gaidar',
#  'chiarelli',
#  'petrocelli',
#  'zbigniew',
#  'gahr',
#  'gerberding',
#  'jassim',
#  'shmuel',
#  'siti',
#  'duelfer',
#  'tahl',
#  'glyn',
#  'muhamed',
#  'yaakov',
#  'raed',
#  'renaud',
#  'pettigrew',
#  'adrien',
#  'zahl',
#  'ghanem',
#  'barham',
#  'udall',
#  'fahr',
#  'racan',
#  'vries',
#  'kroes',
#  'ehs',
#  'rashad',
#  'klestil',
#  'sokol',
#  'agca',
#  'isaias',
#  'eichel',
#  'wozniak',
#  'yoriko',
#  'fratto',
#  'colton',
#  'bair',
#  'schulte',
#  'gfk',
#  'mijailovic',
#  'linton',
#  'aref',
#  'lahl',
#  'rudeina',
#  'canfield',
#  'courtenay',
#  'rayner',
#  'sahb',
#  'heikki',
#  'acebes',
#  'leonie',
#  'zow',
#  'suleman',
#  'knauss',
#  'jayasinghe',
#  'marcin',
#  'oren',
#  'nurhasyim',
#  'begg',
#  'jaeger',
#  'eberhard',
#  'susana',
#  'indyk',
#  'gool',
#  'oleksandr',
#  'vladimiro',
#  'svoboda',
#  'rco',
#  'guyer',
#  'nizar',
#  'kamil',
#  'weise',
#  'vik',
#  'sgrena',
#  'batiste',
#  'raht',
#  'piet',
#  'raffaele',
#  'ghassan',
#  'joost',
#  'volodymyr',
#  'akhmad',
#  'briefing.com',
#  'saleem',
#  'weingarten',
#  'zandi',
#  'nadeem',
#  'zuhri',
#  'sehn',
#  'hehr',
#  'bahk',
#  'gahn',
#  'izzat',
#  'antoni',
#  'dek',
#  'judson',
#  'georgios',
#  'severin',
#  'marcinkiewicz',
#  'sonthi',
#  'khawaja',
#  'ramdin',
#  'cornelis',
#  'gettelfinger',
#  'yegor',
#  'lomas',
#  'lauro',
#  'riad',
#  'alassane',
#  'poot',
#  'ahsan',
#  'józef',
#  'bigley',
#  'sheed',
#  'gade',
#  'hammoud',
#  'behn',
#  'yakovlev',
#  'rhee',
#  'warfield',
#  'everson',
#  'kye',
#  'dervis',
#  'shar',
#  'vershbow',
#  'zafar',
#  'dorn',
#  'vaz',
#  'bahl',
#  'parke',
#  'jakub',
#  'steh',
#  'toth',
#  'omi',
#  'mykola',
#  'martine',
#  'koda',
#  'crean',
#  'durrani',
#  'adan',
#  'reer',
#  'muasher',
#  'henk',
#  'sameer',
#  'álvarez',
#  'sahr',
#  'steny',
#  'alexey',
#  'sood',
#  'gunness',
#  'ange',
#  'milinkevich',
#  'kidwa',
#  'soledad',
#  'muniz',
#  'karam',
#  'adolphe',
#  '------------------',
#  'schori',
#  'carriles',
#  'hatem',
#  'kadirgamar',
#  'hanif',
#  'zerhouni',
#  'lanny',
#  'yakovenko',
#  'pekka',
#  'shingo',
#  'crispin',
#  'cockburn',
#  'hijazi',
#  'libeskind',
#  'malin',
#  'riza',
#  'yel',
#  'sucden',
#  'kyprianou',
#  'mzoudi',
#  'pettit',
#  'murtaza',
#  'yahp',
#  'steinbrueck',
#  'gallois',
#  'ranjan',
#  'chiara',
#  'samarasinghe',
#  'dozier',
#  'eitan',
#  'hein',
#  'luhn',
#  'tani',
#  'schmitz',
#  'koht',
#  'sreesanth',
#  'nieves',
#  'ullah',
#  'speicher',
#  'jacek',
#  'rickc',
#  'foutch',
#  'saenz',
#  'deez',
#  'zurab',
#  'kellner',
#  'dalia',
#  'pih',
#  'singson',
#  'zoltan',
#  'sajid',
#  'banach',
#  'klaas',
#  'vaile',
#  'moussawi',
#  'awadallah',
#  'sabliere',
#  'jigme',
#  'arno',
#  'doria',
#  'gohr',
#  'korzhakov',
#  'radu',
#  'microbiologist',
#  'granato',
#  'heffernan',
#  'mannion',
#  'collinson',
#  'piot',
#  'maciel',
#  'al-din',
#  'neff',
#  'dimas',
#  'karsten',
#  'harel',
#  'purnomo',
#  'charest',
#  '404-526-5429',
#  'urz',
#  'azimi',
#  'janvier',
#  'haroon',
#  'mansoor',
#  'geir',
#  'siraj',
#  'hannes',
#  'alina',
#  'aloysius',
#  'merwe',
#  'lundberg',
#  'sten',
#  'eder',
#  'tiberi',
#  'westerwelle',
#  'trần',
#  'nikolaus',
#  'alwan',
#  'mokhtar',
#  'eef',
#  'platts',
#  'gerson',
#  'fogel',
#  'lanza',
#  'emanuele',
#  'miert',
#  'joann',
#  'zhuh',
#  'sabbah',
#  'seitz',
#  'mariusz',
#  'siddique',
#  'kloh',
#  'randi',
#  'zandt',
#  'masayoshi',
#  'kuhb',
#  'comscore',
#  'borja',
#  'choy',
#  'berris',
#  'zvi',
#  'sylvestre',
#  'janusz',
#  'eckert',
#  'myriam',
#  'hilde',
#  'hanescu',
#  'qari',
#  'lansana',
#  'ashish',
#  '404-526-7282',
#  'hak',
#  'ejup',
#  'asghar',
#  'mesereau',
#  'shiller',
#  'kcb',
#  'lenihan',
#  'colville',
#  'dror',
#  'satish',
#  'bodman',
#  'esparza',
#  'gautier',
#  'vinogradov',
#  'deming',
#  'sayyed',
#  'keh',
#  'zhoo',
#  'burkle',
#  'hahb',
#  'zahid',
#  'nashiri',
#  'ramzan',
#  'wojciech',
#  'naftogaz',
#  'weng',
#  'ligety',
#  'foale',
#  'guofang',
#  'fayez',
#  'kirill',
#  'bommel',
#  'nicolai',
#  'adem',
#  'cheema',
#  'yana',
#  'dupuy',
#  'wessels',
#  'aharon',
#  'kyser',
#  'reichel',
#  'sherrod',
#  'moura',
#  'levan',
#  'rend',
#  'jourdain',
#  'capellas',
#  'penfield',
#  'rauch',
#  'maroni',
#  'dawood',
#  'rutan',
#  'moustapha',
#  'michalis',
#  'natan',
#  'tanzi',
#  'günther',
#  'andrej',
#  'leng',
#  'hatfill',
#  'hassani',
#  'detlev',
#  'dimasi',
#  'illingworth',
#  'ogilvie',
#  'nielson',
#  'ryszard',
#  'debre',
#  'mohn',
#  'kohut',
#  'mcdougall',
#  'backus',
#  'lage',
#  'kors',
#  'lê',
#  'heseltine',
#  'whitson',
#  'tengku',
#  'gamboa',
#  'fauci',
#  'yacoub',
#  'meltzer',
#  'bagley',
#  'risley',
#  'yuriy',
#  'sarkisian',
#  'saiful',
#  'taik',
#  'benedetto',
#  'tedeschi',
#  'henryk',
#  'thiessen',
#  'albin',
#  'hajji',
#  'baran',
#  'victorino',
#  'ueberroth',
#  'scheck',
#  'dietmar',
#  'tibor',
#  'hirvonen',
#  'rattner',
#  'yoshiaki',
#  'wook',
#  'losyukov',
#  'buell',
#  'waldemar',
#  'kleine',
#  's.j.',
#  'takao',
#  'geert',
#  'adolphus',
#  'nemanja',
#  'toshihiko',
#  'sauls',
#  'pyng',
#  'ohn',
#  'zeller',
#  'jochen',
#  'gahl',
#  'howells',
#  'taheri',
#  'bjarne',
#  'llorente',
#  'rezko',
#  'bayard',
#  'muallem',
#  'rustam',
#  'geraint',
#  'nebojsa',
#  'emmet',
#  'wirayuda',
#  'sherpao',
#  'isaacson',
#  'rogozin',
#  'srinivasan',
#  'magen',
#  'yahia',
#  'qiyue',
#  'hoogenband',
#  'montas',
#  'jean-claude',
#  'burdzhanadze',
#  'mattei',
#  'kowalczyk',
#  'gree',
#  'dragoljub',
#  'angelopoulos',
#  'okabe',
#  'hoang',
#  'dunstan',
#  'daraghmeh',
#  'arron',
#  'fadel',
#  'eschenbach',
#  'bertone',
#  'agus',
#  'gani',
#  'sneddon',
#  'arman',
#  'frampton',
#  'issac',
#  'milstein',
#  'ishaq',
#  'zhai',
#  'pavle',
#  'ferre',
#  'zeev',
#  'malloch',
#  'mendelsohn',
#  'sarna',
#  'diez',
#  'hahl',
#  'calyon',
#  'riise',
#  'meridor',
#  'asfour',
#  'amalia',
#  'plouffe',
#  'vassilis',
#  'saca',
#  'zhah',
#  'foh',
#  'fateh',
#  'hagee',
#  'gerrit',
#  'canizares',
#  'spidla',
#  'stockbroking',
#  'moasher',
#  'kym',
#  'fyodorov',
#  'qadi',
#  'hym',
#  'hsia',
#  'tamayo',
#  'udaya',
#  'mees',
#  'reitman',
#  'ramin',
#  'mischa',
#  'eldon',
#  'hollingworth',
#  'isdell',
#  'lászló',
#  'meed',
#  'kiet',
#  'trapp',
#  'zheh',
#  'yair',
#  'gongadze',
#  'alaron',
#  'édouard',
#  'hamel',
#  'mikulas',
#  'dato',
#  'wolfram',
#  'lihn',
#  'dujarric',
#  'dugard',
#  'obaid',
#  'keyser',
#  'komorowski',
#  'faneuil',
#  'delgadillo',
#  'fahn',
#  'turan',
#  'noyes',
#  'runge',
#  'hazen',
#  'denys',
#  'sestak',
#  'fadhil',
#  'fredrick',
#  'iskandar',
#  'canales',
#  'davila',
#  'druyun',
#  'zel',
#  'ziyi',
#  'jorma',
#  'gaillard',
#  'basuki',
#  'bookman',
#  'alon',
#  'gehr',
#  'creel',
#  'correia',
#  'narciso',
#  'fennell',
#  'guangfa',
#  'kumari',
#  'kinnock',
#  'bijani',
#  'shai',
#  'cecile',
#  'rop',
#  'besser',
#  'joulwan',
#  'ruelas',
#  'funes',
#  'solovyov',
#  'bernier',
#  'elden',
#  'shiokawa',
#  'magda',
#  'xilai',
#  'petros',
#  'zander',
#  'heide',
#  'diab',
#  'raimi',
#  'mashal',
#  'klebold',
#  'lapid',
#  'zainal',
#  'vay',
#  'rigas',
#  'jordaan',
#  'alwaleed',
#  'ivanovich',
#  'thacher',
#  'junaid',
#  'gonsalves',
#  'scholz',
#  'ewald',
#  'benet',
#  'chuckh',
#  'schenk',
#  'goldfarb',
#  'theophilus',
#  'talmadge',
#  'wakil',
#  'yancey',
#  'enderle',
#  'zubak',
#  'serhiy',
#  'ritterbusch',
#  'jabr',
#  'azim',
#  'rodger',
#  'pimentel',
#  'kyoo',
#  'margherita',
#  'teck',
#  'grunwald',
#  'davor',
#  'sandor',
#  'feroz',
#  'whiteside',
#  'hipolito',
#  'cyndi',
#  'tunku',
#  'tshabalala',
#  'norberto',
#  'kweisi',
#  'bakley',
#  'kyong',
#  'wendel',
#  'brazill',
#  'dergarabedian',
#  'fadl',
#  'ferdinando',
#  'alexandros',
#  'yuval',
#  'girolamo',
#  'neufeld',
#  'zhvania',
#  'kha',
#  'marciano',
#  'zarate',
#  'astley',
#  'bacanovic',
#  'javad',
#  'abdirahman',
#  'melania',
#  'broek',
#  'agostino',
#  'matsch',
#  'behl',
#  'shahal',
#  'jehan',
#  'dissanayake',
#  'moceanu',
#  'masaaki',
#  'abid',
#  'kamp',
#  'garvin',
#  'ratcliffe',
#  'alun',
#  'bola',
#  'arkady',
#  'athar',
#  'bhatti',
#  'ashworth',
#  'nakasone',
#  'taub',
#  'haase',
#  'heet',
#  'aghazadeh',
#  'ashfaq',
#  'jalali',
#  'karmi',
#  'thaddeus',
#  'cianci',
#  'shira',
#  'woerth',
#  'kabalu',
#  'brammertz',
#  'hollingsworth',
#  'neuroscientist',
#  'manoel',
#  'hadid',
#  'hartwell',
#  'oswaldo',
#  'corrado',
#  'margarito',
#  'tanweer',
#  'reiffel',
#  'florez',
#  'deshmukh',
#  'consuelo',
#  'esam',
#  'jabar',
#  'hemant',
#  'segura',
#  'kanafani',
#  'vehr',
#  'cordesman',
#  'haan',
#  'scherer',
#  'shean',
#  'owain',
#  '202-887-8320',
#  'seismologist',
#  'wyn',
#  'jubeir',
#  'salameh',
#  'numan',
#  'meijer',
#  'aghajari',
#  'giuliana',
#  'rajeev',
#  'naik',
#  'bassem',
#  'bauman',
#  'frieden',
#  'toma',
#  'tszyu',
#  'shirakawa',
#  'raad',
#  'shuttleworth',
#  'folha',
#  'angeli',
#  'maciej',
#  'wilford',
#  'fawaz',
#  'honore',
#  'ganji',
#  'flemming',
#  'mutua',
#  'juha',
#  'janette',
#  'micheal',
#  'gunes',
#  'geophysicist',
#  'sharkey',
#  'castellanos',
#  'haldane',
#  'itamar',
#  'raouf',
#  'zobel',
#  'dichter',
#  'leen',
#  'luque',
#  'kaddoumi',
#  'farhad',
#  'bhatia',
#  'eran',
#  'tsutsumi',
#  'shehl',
#  'geren',
#  'haro',
#  ...]

# %%
def get_embeddings(word_list,word):
    word_dict = {}
    for i in word_list:
        if i in embeddings.keys():
            word_dict[i] = scipy.spatial.distance.cosine(embeddings[i],embeddings[word])
    return sorted(word_dict, key=word_dict.get)

# %%
def get_answer_with_kmeans(sent,word):
    categories = entities_with_nltk(sent)
    words = get_possible_words(categories)
    timer = ElapsedTimer()
    for i in words:
        min_dist = []
        for j in cluster_centers:
            if i in embeddings:
                min_dist.append(scipy.spatial.distance.cosine(embeddings[i],j))
            else:
                min_dist.append(9999999)
        if(len(min_dist)>0):
            min_dist = np.array(min_dist)
            c = np.argmin(min_dist)
            words_to_compare = get_embeddings(cluster_dict[c],i)
        for k in words_to_compare:
            if(len(k)==len(word)):
                if compare(k,word):
                    timer.elapsed_time()
                    return k
    return ""

# %% [markdown]
# # By the looks of it, it was able to predict only 167 of 251 words but at almost 1/10000th of the time taken previously! awesome ain't it?

# %%
results['Answer with KMeans'] = evaluation.apply(lambda x: get_answer_with_kmeans(x.Meaning, x.Masked), axis=1)
# Out:
# the
# ,
# .
# of
# to
# and
# in
# a
# "
# 's
# for
# -
# that
# on
# is
# was
# said
# with
# he
# as
# it
# by
# at
# (
# )
# from
# his
# ''
# ``
# an
# be
# has
# are
# have
# but
# were
# not
# this
# who
# they
# had
# i
# which
# will
# their
# :
# or
# its
# one
# after
# new
# been
# also
# we
# would
# two
# more
# '
# first
# about
# up
# when
# year
# there
# all
# --
# out
# she
# other
# people
# n't
# her
# percent
# than
# over
# into
# last
# some
# government
# time
# $
# you
# years
# if
# no
# world
# can
# three
# do
# ;
# president
# only
# state
# million
# could
# us
# most
# _
# against
# u.s.
# so
# them
# what
# him
# united
# during
# before
# may
# since
# many
# while
# where
# states
# because
# now
# city
# made
# like
# between
# did
# just
# national
# day
# country
# under
# such
# second
# then
# company
# group
# any
# through
# china
# four
# being
# down
# war
# back
# off
# south
# american
# minister
# police
# well
# including
# team
# international
# week
# officials
# still
# both
# even
# high
# part
# told
# those
# end
# former
# these
# make
# billion
# work
# our
# home
# school
# party
# house
# old
# later
# get
# another
# tuesday
# news
# long
# five
# called
# 1
# wednesday
# military
# way
# used
# much
# next
# monday
# thursday
# friday
# game
# here
# ?
# should
# take
# very
# my
# north
# security
# season
# york
# how
# public
# early
# according
# several
# court
# say
# around
# foreign
# 10
# until
# set
# political
# says
# market
# however
# family
# life
# same
# general
# –
# left
# good
# top
# university
# going
# number
# major
# known
# points
# won
# six
# month
# dollars
# bank
# 2
# iraq
# use
# members
# each
# area
# found
# official
# sunday
# place
# go
# based
# among
# third
# times
# took
# right
# days
# local
# economic
# countries
# see
# best
# report
# killed
# held
# business
# west
# does
# own
# %
# came
# law
# months
# women
# 're
# power
# think
# service
# children
# bush
# show
# /
# help
# chief
# saturday
# system
# john
# support
# series
# play
# office
# following
# me
# meeting
# expected
# late
# washington
# games
# european
# league
# reported
# final
# added
# without
# british
# compel
# jungles
# coups
# endeavors
# organizes
# piling
# shuttered
# multicultural
# cabinets
# martyrdom
# bookings
# mughal
# password
# gunshots
# shenyang
# buddhists
# confrontational
# staunchly
# malpractice
# contradicted
# instrumentation
# relic
# incarcerated
# eroding
# conglomerates
# distinctions
# insignificant
# soloist
# minibus
# faltered
# flushing
# airmen
# sediment
# wye
# 1850s
# gorazde
# upbringing
# exemplary
# dialogues
# translating
# noises
# bankruptcies
# rehearsals
# nypd
# first-team
# healed
# rubbish
# gigs
# prius
# boycotting
# boj
# specifying
# rightful
# outpouring
# burdened
# showcased
# intercourse
# nesting
# subversion
# rained
# unleash
# originate
# preside
# auditing
# sixteenth
# exited
# supplementary
# gathers
# residual
# qassam
# sanitary
# overboard
# pamphlet
# wrongful
# converged
# manually
# whopping
# unravel
# thirteenth
# unruly
# scarcely
# extinguished
# demos
# brackets
# primetime
# inputs
# restructured
# slowest
# ridges
# excelled
# launcher
# poaching
# paramedics
# jirga
# funnel
# artworks
# kinmen
# inaction
# comedians
# beige
# dispel
# appraisal
# ecumenical
# outback
# alamo
# pacifist
# reconstruct
# complying
# toughness
# disposition
# ntsb
# jittery
# emperors
# hearted
# euphoria
# decency
# colonization
# scrimmage
# empirical
# worthless
# tyres
# undersea
# floodwaters
# cyclones
# obscurity
# wrenching
# 52-week
# touting
# agrarian
# bluntly
# skyscrapers
# mta
# skorea
# bonding
# regimen
# truths
# subversive
# georgians
# freezer
# oppressed
# newscasts
# converge
# waive
# statistic
# contradictions
# motivate
# escorting
# rushes
# observance
# nonviolent
# 2,700
# evaluations
# realignment
# pasture
# skirmish
# storied
# 2050
# evacuating
# refinancing
# colder
# downloading
# fulfillment
# seniority
# vernacular
# constrained
# friendships
# cede
# conclusive
# prototypes
# undermines
# unseat
# contacting
# tremors
# necessities
# stints
# 2018
# unscathed
# necks
# revising
# polluting
# 3,200
# cutoff
# coronary
# privatized
# sufferers
# ceylon
# scanners
# carmakers
# mudslides
# hercegovina
# thinkers
# wherein
# hospice
# stressful
# cyclical
# exploratory
# rooftops
# compile
# retrial
# envision
# watered
# harsher
# repository
# parisian
# commence
# watering
# evacuations
# escorts
# erroneous
# stacks
# boating
# neared
# fourteenth
# mid-1960s
# eyewitnesses
# lakeside
# interruption
# unjustified
# fringes
# impede
# uprooted
# marginalized
# mulling
# scarves
# perilous
# confer
# ascension
# seeding
# pursues
# real-time
# blending
# heartfelt
# cheaply
# payout
# tending
# uninhabited
# srpska
# ramifications
# detaining
# acquainted
# equaliser
# axle
# intersections
# harrowing
# occupations
# tack
# overt
# inquest
# altitudes
# chertoff
# entrepreneurship
# entertainers
# referral
# experimented
# dedicate
# anfield
# sodomy
# arisen
# electrified
# blacklist
# pharmacies
# taping
# linemen
# hunts
# predicament
# devoid
# livelihoods
# dailies
# leftists
# bedrock
# aum
# melee
# reunions
# formula_4
# agendas
# syndication
# krajina
# unannounced
# pastors
# masse
# stopover
# excise
# bearish
# colombians
# north-south
# reprocessing
# p.o.
# booby
# hmo
# nightfall
# nominally
# broadened
# spin-off
# paratroopers
# soliciting
# elects
# hectic
# dilapidated
# wetland
# contexts
# penetrated
# oppressive
# doorstep
# discretionary
# arrears
# footballers
# posh
# chores
# luftwaffe
# hailing
# heroism
# mediating
# recoup
# coupon
# exhaustive
# mutilated
# groundwater
# refunds
# remittances
# lunches
# argentines
# bellwether
# swapping
# lukewarm
# regroup
# napoleonic
# glut
# overran
# closings
# philanthropic
# mainline
# legalized
# adherents
# stymied
# subsidize
# unwelcome
# pacts
# premiers
# compromising
# zinni
# downstairs
# auditions
# charters
# gridlock
# budgeted
# contradict
# dynasties
# earners
# disband
# shrouded
# overcrowding
# tsar
# vioxx
# seaport
# introductory
# boasting
# trolley
# eruptions
# runners-up
# resounding
# defections
# foresee
# firings
# combative
# grossing
# panorama
# obstructing
# calamity
# cremated
# relocating
# counterfeiting
# comrade
# entice
# energized
# elevations
# freezes
# blazes
# signings
# indiscriminate
# signalling
# usable
# protectionist
# conspirators
# obligatory
# edgy
# intra
# wastes
# overheating
# reminders
# renovate
# incarceration
# forbidding
# levees
# mondays
# societal
# acquaintances
# embarking
# goalless
# estimating
# compatibility
# hinges
# unitary
# unexplained
# tabloids
# parcels
# subscriptions
# lest
# defused
# rappers
# bureaus
# connectivity
# empower
# fewest
# approvals
# 3,600
# excursion
# merchandising
# stagnation
# analogous
# epidemics
# diverting
# inflow
# maturing
# abstained
# abstinence
# cohesion
# transnational
# captaincy
# zedong
# 1,900
# affiliations
# hijack
# pregnancies
# whichever
# unload
# diversification
# bestseller
# crewmen
# ombudsman
# writ
# incremental
# harassing
# emboldened
# encompass
# attributable
# aborigines
# debilitating
# rebelled
# tenuous
# deserving
# homicides
# peerage
# mastery
# undue
# raisers
# sleeper
# taxing
# percentages
# frontiers
# envelopes
# unifying
# etiquette
# revitalize
# misgivings
# wield
# contemplated
# bondholders
# bosnians
# inaccessible
# locating
# subsistence
# queue
# traverse
# regeneration
# revolutionaries
# miraculous
# number-one
# qtr
# democratization
# decorating
# crooked
# batons
# airbase
# informants
# bloodied
# pre-season
# passers
# thematic
# directives
# mansions
# recounting
# rhetorical
# hampering
# submissions
# placid
# harbors
# 1950-53
# gamblers
# scorched
# vending
# functioned
# amalgamated
# precedence
# grisly
# sporadically
# decimated
# adoptive
# migrating
# patiently
# airlifted
# stretcher
# ordinarily
# hotbed
# glitch
# gauges
# orthodoxy
# rangoon
# 212-556-4204
# governorship
# ills
# commemorates
# hectare
# implicitly
# polarized
# contemplate
# vertically
# ignition
# congested
# biking
# bumpy
# shorten
# elites
# stifling
# tantamount
# c-130
# timeout
# darkened
# sochi
# pro-
# unwillingness
# outpatient
# malfunction
# initiating
# monopolies
# solicit
# cac-40
# offensively
# privatize
# mofa
# rationing
# diocesan
# scraps
# hideouts
# attrition
# liturgy
# streetcar
# two-thirds
# industrialization
# juncture
# frenzied
# importation
# unsolicited
# meteorology
# hospitalised
# instructional
# southerners
# penetrating
# constitutionality
# aloft
# csx
# urumqi
# veered
# forfeit
# sympathies
# cadre
# tories
# afternoons
# kurd
# forgo
# impairment
# reinstatement
# lawns
# proficiency
# debit
# outage
# landowner
# unregulated
# realms
# scarcity
# recruiters
# practised
# regimental
# emptive
# coalitions
# rightist
# unlicensed
# commissioning
# multiparty
# southward
# subpoenaed
# firefighting
# binge
# 3:00
# scrutinized
# immunization
# levee
# inconvenience
# bypassed
# elective
# disturb
# industrialised
# unsustainable
# gambari
# awash
# undo
# hydropower
# voyages
# depositors
# postings
# postponing
# sharpest
# inhalation
# freer
# straining
# nhs
# east-west
# reclamation
# glittering
# neolithic
# tallies
# hinge
# unchecked
# exhibiting
# totalitarian
# unloading
# parochial
# methamphetamine
# orchestrating
# surcharge
# childbirth
# arraigned
# pediatrics
# venezuelans
# tuesdays
# stamina
# liturgical
# deductible
# cambodians
# discrepancy
# publicize
# presenters
# undesirable
# willingly
# bailouts
# habsburg
# shinzo
# bypassing
# massively
# prewar
# darkest
# medically
# angled
# malays
# contraception
# 10-month
# wineries
# accommodating
# excursions
# sizeable
# voucher
# wealthier
# 10-minute
# pretrial
# thoroughfare
# fervent
# jordanians
# clientele
# takeovers
# exiting
# disparities
# redress
# 15-minute
# demolish
# arraignment
# premeditated
# suppressing
# throttle
# unifil
# restraints
# showcasing
# brochure
# rapprochement
# multiplayer
# reformists
# unsigned
# interdisciplinary
# paychecks
# archival
# refiners
# reorganize
# subways
# tabs
# nearer
# spawning
# mpg
# gardeners
# erroneously
# inhumane
# mysteriously
# unprofor
# droughts
# workload
# exhibitors
# pregame
# tidy
# eavesdropping
# unsuitable
# 2010-11
# intersects
# fairways
# jeeps
# english-language
# southbound
# gnp
# accumulating
# co-operative
# abolishing
# corrective
# empires
# long-distance
# cross-country
# mishap
# unexploded
# contraband
# gamers
# uninterrupted
# refrigerate
# extravaganza
# harvests
# conduit
# peninsular
# quieter
# upturn
# secluded
# aisles
# leeway
# gunfight
# ligaments
# dispatching
# convening
# definitively
# fractious
# left-wing
# unprofitable
# normalcy
# jeddah
# campers
# twenty-five
# narratives
# disproportionately
# prerequisite
# appropriation
# streamlining
# arsenals
# academically
# installments
# papacy
# northbound
# exceedingly
# overflow
# nestled
# undetermined
# embankment
# non-fiction
# continual
# usaf
# reputations
# mitigation
# sorties
# secretary-general
# ict
# ringed
# overhauling
# undeveloped
# unconditionally
# climates
# townspeople
# volunteering
# airfields
# exhausting
# demarcation
# widest
# yanukovich
# licences
# localized
# previews
# abortive
# theorists
# unsold
# broadest
# transmitters
# unbroken
# hiked
# anti-aircraft
# internship
# disappointments
# rupture
# asiad
# kalashnikov
# quarantined
# roundtable
# labourers
# landlocked
# hospitalization
# peacetime
# anxiously
# encountering
# 20-minute
# dissipated
# pensioners
# confiscation
# zapatista
# neighbourhoods
# choppy
# cantonese
# g-20
# intercollegiate
# uniformly
# harshest
# disable
# milder
# precondition
# clampdown
# seabed
# lunchtime
# reliably
# basing
# discrepancies
# preachers
# tenths
# enquiry
# tsunamis
# 27-nation
# extracurricular
# nationalized
# rwandans
# strayed
# confines
# liftoff
# censors
# shipyards
# outflow
# caters
# jogging
# accessing
# retroactive
# a-year
# undergraduates
# searchers
# illustrating
# cctv
# landscaping
# interfaith
# monthlong
# sitcoms
# brides
# shortfalls
# usgs
# temblor
# yasukuni
# inflicting
# counterinsurgency
# buyback
# mobilizing
# right-wing
# playable
# stewards
# wrest
# fiercest
# plainclothes
# condolence
# circulate
# centrally
# congregational
# islets
# singaporeans
# readership
# socioeconomic
# attaining
# consulates
# strikingly
# canvassing
# repulsed
# modelling
# long-running
# groupings
# uprisings
# at&t
# hijackings
# deterrence
# outnumber
# wellness
# acreage
# conservationists
# industrialists
# on-air
# untold
# zepa
# tenders
# partisanship
# short-term
# co-operation
# sderot
# seamen
# dormitories
# teeming
# laureates
# brothels
# bolshevik
# ascertain
# rosters
# snowstorm
# viewership
# commuting
# unequal
# periphery
# valuations
# wastewater
# awfully
# shoddy
# vets
# 0900
# fdi
# oneself
# irrespective
# lobbed
# unimaginable
# pharmacists
# schoolhouse
# katyusha
# geologists
# daylong
# feats
# landmine
# focussed
# buyouts
# two-story
# revamping
# quds
# superdelegates
# high-profile
# nationalistic
# strenuous
# payouts
# iucn
# golfing
# thunderstorm
# intermittently
# craftsmen
# blu-ray
# boycotts
# goers
# ambushes
# calorie
# secede
# revitalization
# ecfa
# wehrmacht
# peer-reviewed
# viewpoints
# barricaded
# moviegoers
# precedents
# felons
# stances
# tattered
# rifts
# formative
# 732-390-4480
# detour
# tarp
# newsstands
# lankans
# electrification
# sanctuaries
# conscription
# friendlies
# stiffer
# megawatt
# devoting
# vieques
# disrepair
# columnists
# armaments
# salaried
# plebiscite
# annuity
# play-offs
# contiguous
# worshipers
# rmb
# coinciding
# nonsubscribers
# ticketing
# uhf
# nonbinding
# gestapo
# candlelight
# kashmiris
# unionized
# ricans
# revelers
# logistic
# roadways
# state-owned
# vacate
# canaveral
# forensics
# tectonic
# year-round
# prefectural
# eurostar
# ordinances
# joblessness
# misstated
# locales
# cohesive
# fomc
# blockades
# commemorations
# navies
# weyded
# u.s.-china
# incriminating
# shareholding
# interconnected
# rebuttal
# english-speaking
# arbitrarily
# offline
# specialising
# encompassed
# languishing
# shakeup
# tankan
# crackdowns
# drier
# non-swiss
# fatigues
# onshore
# examiners
# undetected
# conrail
# bulletins
# falklands
# non-governmental
# yardage
# citywide
# fundraisers
# dependents
# middle-class
# nongovernmental
# desegregation
# practising
# antiwar
# freeways
# confederates
# 10-point
# arterial
# day-to-day
# convection
# wishers
# depository
# upkeep
# droves
# unsealed
# infrastructures
# jetliners
# hinged
# militaries
# clockwise
# geologic
# undivided
# sponsorships
# swaths
# gazans
# parkland
# tambon
# showrooms
# k-12
# not-for-profit
# bundestag
# high-level
# afield
# volleys
# decision-making
# illan
# headscarf
# epicentre
# untapped
# spaceflight
# vacationers
# petroleos
# co-educational
# spacewalks
# ranching
# working-class
# blighted
# airfare
# underprivileged
# downpours
# majoring
# u.s.-brokered
# non-league
# northwards
# eastwards
# oricon
# a320
# low-income
# devolved
# pageexpress
# guaranty
# u.s.-mexico
# radiological
# tduncan
# inter-county
# mdgs
# at-large
# groundstrokes
# right-of-way
# djlfx
# four-lane
# redrawn
# 404-582-7282
# http://www.tse.or.jp
# ayp
# jtwc
# coursework
# non-mandatory
# eighteens
# dehestan
# pfoutch
# 800-950-3739
# olyā
# period_1
# text-align
# soflá
# bālā
# zhahk
# arodriguez
# 1-800-535-4425
# hahj
# rickm
# 572-1800
# am.-5
# valign
# #ukqeqtqszb
# latwp@ldc.upenn.edu
# 02107
# rickd
# bessonette
# 44-1-71
# 353-1175
# 0d3fb
# midcap50
# jhaw
# testthis
# prohibitivo
# period_none
# hohst
# tuhv
# mihz
# rehts
# non-obligatory
# joohm
# d00l
# zhohn
# rohch
# rohsh
# tahsh
# vehs
# zheed
# hahmz
# hoond
# kroyts
# dashst
# i-qula
# gwih
# 1-888-698-6397
# 1-888-nyt
# period_3
# zhehr
# 972-3550
# whahng
# http://en.wikipedia.org/wiki/wikipedia:footnotes
# http://www.coxnews.com/2000
# period_2
# lahv
# 404-222-2002
# vursh
# 313.222.2738
# .1282
# 313.222.2260
# 313.222.2480
# 499-3339
# http://www.stuffit.com
# klahk
# pwehr
# pyahng
# period_4
# 1772-1945
# 94120
# rehz
# brohd
# __________________________________
# chāh-e
# mv/pi
# www.startext.net:www.arlington.net
# qeshlāq-e
# nytnews@nytimes.com
# page1-nyt
# kalāteh-ye
# mazra‘eh
# kolā
# #ukqaqs
# chāh
# #ukqaqfqs
# #ukqaqsqf
# 10036-3959
# īyeh
# kandī
# period_5
# ivaxcp
# maḩalleh
# 404-536-6751
# www.nytsyn
# 1/km
# http://www.netizen.com
# badheaders
# helobogus
# ipnotinmx
# xccikcstar.com
# ḩājjī
# texbudget
# prohertrib
# n.a.-not
# philpins
# #dcdcdc
# 66.143.36.10
# tyahn
# #ukqaqtqszbzszr
# customercare@nytimes.com
# bermand@nytimes.com
# endtag
# florez@nytimes.com
# wmorris@globe.com
# alīābād
# 1-900-xxx
# 1-900-420-8002
# ḩoseynābād
# period_6
# plrt
# webgraphics
# weightlegit
# http://apwebgraphics.ap.org
# bolāgh
# ḩasan
# psydrinae
# value/personal
# mx2004
# kuhdz
# .000660
# 2/km
# ch-oh
# sarā
# .000661
# ḩoseynābād-e
# 1514.25
# job-embedded
# www.gardenlerner.com
# recipeswap
# 233,290,000
# 35px
# cellspacing
# cellpadding
# moḩammadābād
# phertzberg@nytimes.com
# 26-mar
# 30-270
# interbk
# gilbert@globe.com
# 8020000c
# spoolname
# 120-299
# nytfileitnotes.ap.org
# 2.0.6.16
# nytnews
# opportunities_new
# border-style
# gwahng
# runs_griffey
# tax/rent
# workgear
# .000663
# kcfw2.kcstar.com
# nasdaq100tr
# genlelec
# qnix
# coludata.co.uk
# edelhausen
# runs_arodriguez
# non-act
# vosţá
# catdgory
# 212-621-1595
# 27-mar
# 0,467
# nokiacorp
# svahng
# .2574
# bases_cedeno
# timewrn
# swallow-like
# http://www.co.mo.md.us
# goals_none
# onlyendpar
# bases_tgoodwin
# http://yang.sprl.umich.edu
# bases_lcastillo
# bacskiskuncounty.gif
# http://www.oklahomacitynationalmemorial.org
# 404-222-8268
# the
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-6e8e5c0a290d> in <module>
# ----> 1 results['Answer with KMeans'] = evaluation.apply(lambda x: get_answer_with_kmeans(x.Meaning, x.Masked), axis=1)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     288             for i, v in enumerate(series_gen):
#     289                 # ignore SettingWithCopy here in case the user mutates
# --> 290                 results[i] = self.f(v)
#     291                 if isinstance(results[i], ABCSeries):
#     292                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-73-6e8e5c0a290d> in <lambda>(x)
# ----> 1 results['Answer with KMeans'] = evaluation.apply(lambda x: get_answer_with_kmeans(x.Meaning, x.Masked), axis=1)
#
# <ipython-input-72-2941fd72221b> in get_answer_with_kmeans(sent, word)
#      13             min_dist = np.array(min_dist)
#      14             c = np.argmin(min_dist)
# ---> 15             words_to_compare = get_embeddings(cluster_dict[c],i)
#      16         for k in words_to_compare:
#      17             if(len(k)==len(word)):
#
# <ipython-input-71-fbc48ed6da13> in get_embeddings(word_list, word)
#       4         print(i)
#       5         if i in embeddings.keys():
# ----> 6             word_dict[i] = scipy.spatial.distance.cosine(embeddings[i],embeddings[word])
#       7     return sorted(word_dict, key=word_dict.get)
#
# KeyError: 'Greek'

# %%
results[results['Answer with KMeans']==""]

# %%
results[results['Answer']==results['Answer with KMeans']]
# Out:
#           Masked                                            Meaning  \
# 1        _ecei_e             get something; come into possession of
# 3          t__sh       worthless material that is to be disposed of
# 4       de_aw_r_  a river that rises in the Catskills in southea...
# 6    ic__a_e_ron           any polyhedron having twenty plane faces
# 8       _ala_si_  a constitutional monarchy in southeastern Asia...
# ..           ...                                                ...
# 245         b_ut                                            (sports
# 246       hic_e_  a small inflamed elevation of the skin; a pust...
# 247           no                                         a negative
# 248      sol_e_t  a liquid substance capable of dissolving other...
# 250  co__i_at_on  something that is compiled (as into a single b...
#
#           Answer Answer with KMeans
# 1        receive            receive
# 3          trash              trash
# 4       delaware           delaware
# 6    icosahedron        icosahedron
# 8       malaysia           malaysia
# ..           ...                ...
# 245         bout               bout
# 246       hickey             hickey
# 247           no                 no
# 248      solvent            solvent
# 250  combination        combination
#
# [130 rows x 4 columns]

# %%
results
# Out:
#           Masked                                            Meaning  \
# 0        co__nth  the modern Greek port near the site of the anc...
# 1        _ecei_e             get something; come into possession of
# 2        _ollag_  a paste-up made by sticking together pieces of...
# 3          t__sh       worthless material that is to be disposed of
# 4       de_aw_r_  a river that rises in the Catskills in southea...
# ..           ...                                                ...
# 246       hic_e_  a small inflamed elevation of the skin; a pust...
# 247           no                                         a negative
# 248      sol_e_t  a liquid substance capable of dissolving other...
# 249        _ump_                          resembling a garbage dump
# 250  co__i_at_on  something that is compiled (as into a single b...
#
#           Answer Answer with KMeans
# 0        corinth
# 1        receive            receive
# 2        collage
# 3          trash              trash
# 4       delaware           delaware
# ..           ...                ...
# 246       hickey             hickey
# 247           no                 no
# 248      solvent            solvent
# 249        lumpy              jumps
# 250  combination        combination
#
# [251 rows x 4 columns]

# %%
results.to_csv('results_with_kmeans.csv')

# %% [markdown]
# # I had so much fun coding this! I definitely learnt  a lot, any suggestions to improve this are welcome :)
